# %%
import torch
import numpy as np
import matplotlib.pyplot as plt

# %%
bif_data_model = torch.load("../results/2026-05-19/full_run_18-47-16_lorenz63_shPLRNN/shPLRNN_features_1_splitting_True/seed_00/bifurcation_data.pth")
# torch.load("../results/2026-05-19/full_run_18-47-16_lorenz63_shPLRNN/shPLRNN_features_1_splitting_True/seed_00/wasserstein_distances.pth")

# %%
bif_data_model["bifurcation_points"][0]

# %%
bif_data_true = np.load("../data/lorenz63/bifurcation_data.npz")

# %%
bif_data_true["id_extrema_counts"]

# %%
for a in bif_data_true:
    print(a)
